# %% [markdown]
# # Group 10
#
# ## Group Members: Ilia, Mai, Martin, Ryan
#
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# # Overview
#
# Our group is using pandas to import two datasets to clean and transform them before loading them into PostgresSQL. The two datasets are a csv files from Kaggle, one is drinks.csv and the second one is unemployment analysis.csv.
#
# Since the data for drinks.csv is for the year 2010, we decided to clean the Unemployment Analysis.csv and select picked the year 2010. then merged the two datasets together to form the new dataframe. Both datasets showed 153 countries on alcohol consumption and unemployment rate.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, inspect

# %% [markdown]
# # Extract
#
# Our group imported two csv data, drinks.csv, and unemployment analysis.csv to use for this project. The two datasets were stored in our repository in the folder name data.

# %%
# Store file path in a variable
drinks = "data/drinks.csv"
unemployment = "data/unemployment analysis.csv"

# %%
# Read our Data file with pandas library
drinks_df = pd.read_csv(drinks)
unemployment_df = pd.read_csv(unemployment)

# %%
# Show Drinks dataframe
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
# Show unemployment dataframe
unemployment_df.rename(columns={'Country Name':'country'}, inplace=True)

# %%
# Change a name of the countries in drinks_df
drinks_df["country"] = drinks_df["country"].replace({'USA':'United States of America', 'Russian Federation':'Russia', 'Congo':'Republic of Congo', 'DR Congo':'Democratic Republic of the Congo', 'Tanzania':'United Republic of Tanzania', 'Somalia':'Somaliland'})

# %%
# Change a name of the countries in unemployment_df
unemployment_df["country"] = unemployment_df["country"].replace({'United States':'United States of America',  'Russian Federation':'Russia', 'Egypt, Arab Rep.':'Egypt', 'Congo, Rep.':'Republic of Congo', 'Congo, Dem. Rep.':'Democratic Republic of the Congo', 'Tanzania':'United Republic of Tanzania', 'Somalia':'Somaliland', 'Turkiye':'Turkey', 'Venezuela, RB':'Venezuela', 'Iran, Islamic Rep.':'Iran'})

# %%
# Reference multiple columns within a dataframe
cleaned_unemployment_df = unemployment_df[['country', 'Country Code', '2010']]

# %%
# Show Cleaned Unemployment dataframe
cleaned_unemployment_df
# Out:
#                          country Country Code   2010
# 0    Africa Eastern and Southern          AFE   6.87
# 1                    Afghanistan          AFG  11.35
# 2     Africa Western and Central          AFW   4.55
# 3                         Angola          AGO   9.43
# 4                        Albania          ALB  14.09
# ..                           ...          ...    ...
# 230                        Samoa          WSM   5.73
# 231                  Yemen, Rep.          YEM  12.83
# 232                 South Africa          ZAF  24.68
# 233                       Zambia          ZMB  13.19
# 234                     Zimbabwe          ZWE   5.21
#
# [235 rows x 3 columns]

# %%
# dropping all entries for countries not found in the 'drinks_df' dataframe
trimmed_data = cleaned_unemployment_df[cleaned_unemployment_df.country.isin(drinks_df.country)]
trimmed_data
# Out:
#                   country Country Code   2010
# 1             Afghanistan          AFG  11.35
# 3                  Angola          AGO   9.43
# 4                 Albania          ALB  14.09
# 6    United Arab Emirates          ARE   2.48
# 7               Argentina          ARG   7.71
# ..                    ...          ...    ...
# 228               Vanuatu          VUT   1.85
# 230                 Samoa          WSM   5.73
# 232          South Africa          ZAF  24.68
# 233                Zambia          ZMB  13.19
# 234              Zimbabwe          ZWE   5.21
#
# [161 rows x 3 columns]

# %%
# Merge the Drinks and unemployment dataframes
cleaned_df = drinks_df.merge(cleaned_unemployment_df, how='inner', on='country')

# %%
cleaned_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3         Angola            217               57             45
# 4      Argentina            193               25            221
# ..           ...            ...              ...            ...
# 156      Vanuatu             21               18             11
# 157    Venezuela            333              100              3
# 158      Vietnam            111                2              1
# 159       Zambia             32               19              4
# 160     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol Country Code   2010
# 0                             0.0          AFG  11.35
# 1                             4.9          ALB  14.09
# 2                             0.7          DZA   9.96
# 3                             5.9          AGO   9.43
# 4                             8.3          ARG   7.71
# ..                            ...          ...    ...
# 156                           0.9          VUT   1.85
# 157                           7.7          VEN   7.11
# 158                           2.0          VNM   1.11
# 159                           2.5          ZMB  13.19
# 160                           4.7          ZWE   5.21
#
# [161 rows x 7 columns]

# %%
# Renamed columns
cleaned_combined_data = cleaned_df.rename(columns={"2010" : "unemployment_rate", "Country Code" : "Country_Code"})
cleaned_combined_data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3         Angola            217               57             45
# 4      Argentina            193               25            221
# ..           ...            ...              ...            ...
# 156      Vanuatu             21               18             11
# 157    Venezuela            333              100              3
# 158      Vietnam            111                2              1
# 159       Zambia             32               19              4
# 160     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol Country_Code  unemployment_rate
# 0                             0.0          AFG              11.35
# 1                             4.9          ALB              14.09
# 2                             0.7          DZA               9.96
# 3                             5.9          AGO               9.43
# 4                             8.3          ARG               7.71
# ..                            ...          ...                ...
# 156                           0.9          VUT               1.85
# 157                           7.7          VEN               7.11
# 158                           2.0          VNM               1.11
# 159                           2.5          ZMB              13.19
# 160                           4.7          ZWE               5.21
#
# [161 rows x 7 columns]

# %%
# Remove 'Country_Code' column
cleaned_combined_data.drop('Country_Code', axis=1, inplace=True)
cleaned_combined_data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3         Angola            217               57             45
# 4      Argentina            193               25            221
# ..           ...            ...              ...            ...
# 156      Vanuatu             21               18             11
# 157    Venezuela            333              100              3
# 158      Vietnam            111                2              1
# 159       Zambia             32               19              4
# 160     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol  unemployment_rate
# 0                             0.0              11.35
# 1                             4.9              14.09
# 2                             0.7               9.96
# 3                             5.9               9.43
# 4                             8.3               7.71
# ..                            ...                ...
# 156                           0.9               1.85
# 157                           7.7               7.11
# 158                           2.0               1.11
# 159                           2.5              13.19
# 160                           4.7               5.21
#
# [161 rows x 6 columns]

# %%
# Set Country column as an index
cleaned_combined_data.set_index('country')
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Angola                 217               57             45
# Argentina              193               25            221
# ...                    ...              ...            ...
# Vanuatu                 21               18             11
# Venezuela              333              100              3
# Vietnam                111                2              1
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol  unemployment_rate
# country
# Afghanistan                           0.0              11.35
# Albania                               4.9              14.09
# Algeria                               0.7               9.96
# Angola                                5.9               9.43
# Argentina                             8.3               7.71
# ...                                   ...                ...
# Vanuatu                               0.9               1.85
# Venezuela                             7.7               7.11
# Vietnam                               2.0               1.11
# Zambia                                2.5              13.19
# Zimbabwe                              4.7               5.21
#
# [161 rows x 5 columns]

# %%
# save cleaned datasets to 'cleaned-datasets' directory
cleaned_combined_data.to_csv('cleaned-datasets/cleaned_combined_data.csv', index=False)

# %%
# Create database connection
protocol = 'postgresql'
username = 'postgres'
password = 'bootcamp'
host = 'localhost'
port = 5433
database_name = 'AlcoholUnemployment_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
# Confirm tables
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['cleaned_combined_data']

# %%
cleaned_combined_data.to_sql(name='cleaned_combined_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
#     955         template=executemany_values,
#     956         fetch=bool(context.compiled.returning),
#     957         **kwargs
#     958     )
#     960 elif self.executemany_mode & EXECUTEMANY_BATCH:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\psycopg2\extras.py:1270, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269 parts[-1:] = post
# -> 1270 cur.execute(b''.join(parts))
#    1271 if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "cleaned_combined_data_pkey"
# DETAIL:  Key (country)=(Afghanistan) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 cleaned_combined_data.to_sql(name='cleaned_combined_data', con=engine, if_exists='append', index=False)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py:1739, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1727 sql_engine = get_engine(engine)
#    1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    (...)
#    1736     dtype=dtype,
#    1737 )
# -> 1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    1742     frame=frame,
#    1743     name=name,
#    1744     index=index,
#    1745     schema=schema,
#    1746     chunksize=chunksize,
#    1747     method=method,
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#    1752 return total_inserted
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py:1332, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1330     raise ValueError("inf cannot be used with MySQL") from err
#    1331 else:
# -> 1332     raise err
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py:1322, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1319 from sqlalchemy import exc
#    1321 try:
# -> 1322     return table.insert(chunksize=chunksize, method=method)
#    1323 except exc.SQLAlchemyError as err:
#    1324     # GH34431
#    1325     # https://stackoverflow.com/a/67358288/6067848
#    1326     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1327     )|inf can not be used with MySQL"""
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py:950, in SQLTable.insert(self, chunksize, method)
#     947     break
#     949 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 950 num_inserted = exec_insert(conn, keys, chunk_iter)
#     951 if num_inserted is None:
#     952     total_inserted = None
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\io\sql.py:857, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     845 """
#     846 Execute SQL statement inserting data
#     847
#    (...)
#     854    Each item contains a list of values to be inserted
#     855 """
#     856 data = [dict(zip(keys, row)) for row in data_iter]
# --> 857 result = conn.execute(self.table.insert(), data)
#     858 return result.rowcount
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py:1295, in Connection.execute(self, statement, *multiparams, **params)
#    1291     util.raise_(
#    1292         exc.ObjectNotExecutableError(statement), replace_context=err
#    1293     )
#    1294 else:
# -> 1295     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\sql\elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py:1487, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1475 compiled_cache = execution_options.get(
#    1476     "compiled_cache", self.engine._compiled_cache
#    1477 )
#    1479 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1480     dialect=dialect,
#    1481     compiled_cache=compiled_cache,
#    (...)
#    1485     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1486 )
# -> 1487 ret = self._execute_context(
#    1488     dialect,
#    1489     dialect.execution_ctx_cls._init_compiled,
#    1490     compiled_sql,
#    1491     distilled_params,
#    1492     execution_options,
#    1493     compiled_sql,
#    1494     distilled_params,
#    1495     elem,
#    1496     extracted_params,
#    1497     cache_hit=cache_hit,
#    1498 )
#    1499 if has_events:
#    1500     self.dispatch.after_execute(
#    1501         self,
#    1502         elem,
#    (...)
#    1506         ret,
#    1507     )
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1848             branched.close()
#    1850 except BaseException as e:
# -> 1851     self._handle_dbapi_exception(
#    1852         e, statement, parameters, cursor, context
#    1853     )
#    1855 return result
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2030     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2031 elif should_wrap:
# -> 2032     util.raise_(
#    2033         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034     )
#    2035 else:
#    2036     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\engine\base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1786                 break
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#    1792     if self.dialect._has_events:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     949         kwargs = {}
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
#     955         template=executemany_values,
#     956         fetch=bool(context.compiled.returning),
#     957         **kwargs
#     958     )
#     960 elif self.executemany_mode & EXECUTEMANY_BATCH:
#     961     if self.executemany_batch_page_size:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\psycopg2\extras.py:1270, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268     parts.append(b',')
#    1269 parts[-1:] = post
# -> 1270 cur.execute(b''.join(parts))
#    1271 if fetch:
#    1272     result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "cleaned_combined_data_pkey"
# DETAIL:  Key (country)=(Afghanistan) already exists.
#
# [SQL: INSERT INTO cleaned_combined_data (country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, unemployment_rate) VALUES (%(country)s, %(beer_servings)s, %(spirit_servings)s, %(wine_servings)s, %(total_litres_of_pure_alcohol)s, %(unemployment_rate)s)]
# [parameters: ({'country': 'Afghanistan', 'beer_servings': 0, 'spirit_servings': 0, 'wine_servings': 0, 'total_litres_of_pure_alcohol': 0.0, 'unemployment_rate': 11.35}, {'country': 'Albania', 'beer_servings': 89, 'spirit_servings': 132, 'wine_servings': 54, 'total_litres_of_pure_alcohol': 4.9, 'unemployment_rate': 14.09}, {'country': 'Algeria', 'beer_servings': 25, 'spirit_servings': 0, 'wine_servings': 14, 'total_litres_of_pure_alcohol': 0.7, 'unemployment_rate': 9.96}, {'country': 'Angola', 'beer_servings': 217, 'spirit_servings': 57, 'wine_servings': 45, 'total_litres_of_pure_alcohol': 5.9, 'unemployment_rate': 9.43}, {'country': 'Argentina', 'beer_servings': 193, 'spirit_servings': 25, 'wine_servings': 221, 'total_litres_of_pure_alcohol': 8.3, 'unemployment_rate': 7.71}, {'country': 'Armenia', 'beer_servings': 21, 'spirit_servings': 179, 'wine_servings': 11, 'total_litres_of_pure_alcohol': 3.8, 'unemployment_rate': 19.01}, {'country': 'Australia', 'beer_servings': 261, 'spirit_servings': 72, 'wine_servings': 212, 'total_litres_of_pure_alcohol': 10.4, 'unemployment_rate': 5.21}, {'country': 'Austria', 'beer_servings': 279, 'spirit_servings': 75, 'wine_servings': 191, 'total_litres_of_pure_alcohol': 9.7, 'unemployment_rate': 4.82}  ... displaying 10 of 161 total bound parameter sets ...  {'country': 'Zambia', 'beer_servings': 32, 'spirit_servings': 19, 'wine_servings': 4, 'total_litres_of_pure_alcohol': 2.5, 'unemployment_rate': 13.19}, {'country': 'Zimbabwe', 'beer_servings': 64, 'spirit_servings': 18, 'wine_servings': 4, 'total_litres_of_pure_alcohol': 4.7, 'unemployment_rate': 5.21})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
